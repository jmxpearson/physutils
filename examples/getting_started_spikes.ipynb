# %% [markdown]
# Here, we'll illustrate basic uses of the physutils package for handling neuronal spike data.

# %%
import numpy as np
import pandas as pd
import physutils as phys
import matplotlib.pyplot as plt

# %% [markdown]
# We'll load a sample dataset from disk and convert it to an instance of the Spikeset class:

# %%
ts = pd.DataFrame.from_csv('sample_spikes.csv')
spks = phys.SpikeSet.from_timestamps(ts, dt=0.005)
spks.head()
# Out:
# channel  1   2   3   5   7   8   10  11
# unit      1   1   1   1   1   1   1   1
# time
# 0.000     0   0   0   0   0   0   0   0
# 0.005     0   0   0   0   0   0   0   0
# 0.010     0   0   0   0   0   0   0   0
# 0.015     0   0   0   0   0   0   0   0
# 0.020     0   0   0   0   0   0   0   0

# %% [markdown]
# We see that this is a data frame of spike times labeled by the channel and single unit to which they correspond.

# %% [markdown]
# Let's load up some events...

# %%
evts = pd.DataFrame.from_csv('sample_events.csv')
evts.head()
# Out:
#        trial_start_time  this_balloon  trial_type  points  inflate_time  \
# trial
# 0           9201.368937             1           3     104      1.823683
# 1           9207.209476             2           1     250      6.690354
# 2           9215.809370             3           2     257      6.901102
# 3           9226.339949             4           2     127      2.589527
# 4           9233.087626             5           1     369     10.655183
#
#        this_run  result        rt  score  banked  outcome  popped  \
# trial
# 0             1  banked  1.299000     54  10.086   11.622     NaN
# 1             1  popped  0.338344     54     NaN   20.302   19.52
# 2             1  banked  0.891144    261  29.117   30.682     NaN
# 3             1  banked  1.336456    338  35.844   37.361     NaN
# 4             1  banked  0.884876    657  50.235   51.739     NaN
#
#        start inflating  stop inflating  trial_over  trial_start  patient  \
# trial
# 0                7.949          10.085      12.458        6.651       17
# 1               12.829             NaN      21.066       12.492       17
# 2               21.981          29.116      31.582       21.095       17
# 3               32.957          35.843      38.339       31.622       17
# 4               39.251          50.234      52.581       38.368       17
#
#        dataset
# trial
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2

# %% [markdown]
# ...and grab the stop times, dropping trials on which it's missing

# %%
stops = evts['stop inflating'].dropna()
stops
# Out:
# trial
# 0         10.085
# 2         29.116
# 3         35.843
# 4         50.234
# 6         68.059
# 7         74.980
# 9         97.698
# 10       111.234
# 11       118.693
# 12       127.906
# 13       140.218
# 15       157.342
# 16       162.631
# 18       173.615
# 19       179.977
# ...
# 84       743.631
# 85       750.197
# 87       764.011
# 89       784.236
# 90       791.648
# 91       801.344
# 93       810.864
# 94       819.536
# 95       827.233
# 100      857.647
# 101      864.991
# 103      877.488
# 104      886.000
# 105      897.000
# 106      907.345
# Name: stop inflating, Length: 75, dtype: float64

# %% [markdown]
# Now, we can split the spikes dataframe into chunks corresponding to a set of times surrounding each event:

# %%
Tpre = -2
Tpost = 1
chunks, indices = spks.evtsplit(stops, Tpre, Tpost)

# %% [markdown]
# Typically, we'd want to do this to make a peri-stimulus (or peri-event) time histogram, but we can save ourselves a step by using the `psth` function:

# %%
psth = spks.psth(stops, Tpre, Tpost, dt=0.005)

# %% [markdown]
# This is easy to plot:

# %%
fig = psth.plot(title='Firing rate vs time')
plt.show()

# %% [markdown]
# And we can compare with a smoothed version:

# %%
smwid = 0.05
smstr = '\nsmoothing window = {0} ms'.format(int(1000 * smwid))
fig = psth.smooth(0.05).plot(title='Firing rate vs time' + smstr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-41e476e05dfe> in <module>()
#       1 smwid = 0.05
#       2 smstr = '\nsmoothing window = {0} ms'.format(int(1000 * smwid))
# ----> 3 fig = psth.smooth(0.05).plot(title='Firing rate vs time' + smstr)
#       4 plt.show()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'smooth'
