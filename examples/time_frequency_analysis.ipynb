# %% [markdown]
# # Example: Time-Frequency Analysis
#
# Here, we'll illustrate some time-frequency analysis of local field potentials (LFP).

# %% [markdown]
# To begin, do the usual bookkeeping and imports.

# %%
import numpy as np
import pandas as pd
import physutils as phys
import physutils.bootstrap as boot
import physutils.tf as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Fetch some LFP data to play with:

# %%
lfp = phys.LFPset(pd.DataFrame.from_csv("sample_lfp.csv"))
lfp.head()
# Out:
#              17
# time
# 0.000 -0.012048
# 0.005 -0.023140
# 0.010 -0.032884
# 0.015 -0.045864
# 0.020 -0.067374

# %% [markdown]
# Get some example events from a behavioral task, the Balloon Analogue Risk Task (BART):

# %%
evt = pd.DataFrame.from_csv('sample_events.csv')
evt.head()
# Out:
#        trial_start_time  this_balloon  trial_type  points  inflate_time  \
# trial
# 0           9201.368937             1           3     104      1.823683
# 1           9207.209476             2           1     250      6.690354
# 2           9215.809370             3           2     257      6.901102
# 3           9226.339949             4           2     127      2.589527
# 4           9233.087626             5           1     369     10.655183
#
#        this_run  result        rt  score  banked  outcome  popped  \
# trial
# 0             1  banked  1.299000     54  10.086   11.622     NaN
# 1             1  popped  0.338344     54     NaN   20.302   19.52
# 2             1  banked  0.891144    261  29.117   30.682     NaN
# 3             1  banked  1.336456    338  35.844   37.361     NaN
# 4             1  banked  0.884876    657  50.235   51.739     NaN
#
#        start inflating  stop inflating  trial_over  trial_start  patient  \
# trial
# 0                7.949          10.085      12.458        6.651       17
# 1               12.829             NaN      21.066       12.492       17
# 2               21.981          29.116      31.582       21.095       17
# 3               32.957          35.843      38.339       31.622       17
# 4               39.251          50.234      52.581       38.368       17
#
#        dataset
# trial
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2

# %% [markdown]
# Let's compare responses to two sets of events, voluntary stops and unexpected balloon pops:

# %%
stops = evt['stop inflating'].dropna()
pops = evt['popped'].dropna()

# %% [markdown]
# We'll look at a window that begins 1.5 seconds before the event and ends half a second after.

# %%
Tpre = -1.5
Tpost = 0.5

# %% [markdown]
# Now plot a moving window spectrogram that averages across trials:

# %%
window = 0.250
percent_overlap = 0.95
spec = lfp.avg_time_frequency('17', stops, Tpre, Tpost, method='spec', winlen=window, 
                              frac_overlap=percent_overlap)

# %% [markdown]
# For contrast, try a wavelet-based time-frequency analysis:

# %%
wav = lfp.avg_time_frequency('17', stops, Tpre, Tpost, method='wav')

# %% [markdown]
# We can also specify a normalization function to use with `avg_time_frequency`. This is useful because we want to compare changes within each frequency band, which have very different baseline power levels. Builtin options are `norm_by_trial` and `norm_by_mean` (across trials), but both require a baseline window.

# %%
baseline_interval = (-1.5, -1.35)
wav_normed, fig = lfp.avg_time_frequency('17', stops, Tpre, Tpost, method='wav', 
                                         normfun=phys.norm_by_trial(baseline_interval))

# %% [markdown]
# Let's try a contrast plot between two event types:

# %%
contr_tf, fig = lfp.contrast_time_frequency('17', [stops, pops], Tpre, Tpost, method='wav',
                            normfun=phys.norm_by_trial(baseline_interval))

# %% [markdown]
# But are any clusters in this image statistically significant?
#
# Our strategy will be to shuffle labels for the two trial types and take any clusters in the image above a threshold that exceed the size of 95% of those in the null distribution.

# %% [markdown]
# First, we make a dataframe containing relevant events and their labels:

# %%
t0 = pd.DataFrame({'time':stops, 'label':0})
t1 = pd.DataFrame({'time':pops, 'label':1})
alltimes = pd.concat([t0, t1])
alltimes.head()
# Out:
#        label    time
# trial
# 0          0  10.085
# 2          0  29.116
# 3          0  35.843
# 4          0  50.234
# 6          0  68.059

# %% [markdown]
# Next, we get a time-frequency matrix for the time segment corresponding to each event:

# %%
series = lfp.dataframe['17']
tffun = tf.continuous_wavelet
events = alltimes['time']
spectra, taxis, faxis = tf._per_event_time_frequency(series, tffun, events, Tpre, Tpost, normfun=phys.norm_by_trial(baseline_interval))

# %% [markdown]
# Now, we need to set a threshold on the t-statistic for the difference map. We can be pretty liberal with this, since the permutation test will determine the significance of the clusters as a whole.

# %%
thresh = 1.0

# %% [markdown]
# Let's see how this might work for one random relabeling of data:

# %%
labels = np.random.permutation(alltimes['label'])

# %%
pos = boot.make_thresholded_diff(spectra, labels, hi=thresh)
neg = boot.make_thresholded_diff(spectra, labels, lo=-thresh)

# %%
def plot_diff_map(img, taxis, faxis):
    ax = plt.figure().add_subplot(111)
    extent = (taxis[0], taxis[-1], faxis[0], faxis[-1])
    im = tf.NonUniformImage(ax, interpolation=None, extent=extent)
    im.set_data(taxis, faxis, img.T)
    ax.set_xlim(extent[0], extent[1])
    ax.set_ylim(extent[2], extent[3])
    ax.images.append(im)
    plt.colorbar(im)

# %% [markdown]
# Plot t-statistic map, along with positive and negative clusters:

# %%
plot_diff_map(pos.data, taxis, faxis)
plot_diff_map(pos, taxis, faxis)
plot_diff_map(neg, taxis, faxis)

# %%
posclus = boot.label_clusters(pos)
negclus = boot.label_clusters(neg)
plot_diff_map(posclus, taxis, faxis)
plot_diff_map(negclus, taxis, faxis)

# %%
cluster_masses = np.concatenate([boot.get_cluster_masses(pos, posclus), 
                               boot.get_cluster_masses(neg, negclus)])
cluster_masses = cluster_masses[np.nonzero(cluster_masses)]
np.sort(cluster_masses)
# Out:
# array([ -1.13693636e+03,  -3.87588082e+02,  -2.42927139e+02,
#         -1.28267222e+02,  -1.06659590e+02,  -9.20958006e+01,
#         -8.69324847e+01,  -7.61476127e+01,  -6.02858814e+01,
#         -5.08002146e+01,  -4.48815917e+01,  -4.17666415e+01,
#         -4.04926389e+01,  -3.76226578e+01,  -3.69243724e+01,
#         -3.11716304e+01,  -3.02713124e+01,  -2.92399523e+01,
#         -2.56983339e+01,  -2.55057346e+01,  -2.22370340e+01,
#         -2.13989842e+01,  -1.97221171e+01,  -1.96893514e+01,
#         -1.67805471e+01,  -8.40944360e+00,  -8.34680400e+00,
#         -7.78974509e+00,  -7.47867378e+00,  -6.73111669e+00,
#         -5.33840848e+00,  -5.25550681e+00,  -3.42462895e+00,
#         -3.32482370e+00,  -3.29480863e+00,  -3.12190385e+00,
#         -3.06583778e+00,  -2.02012303e+00,  -1.07183867e+00,
#         -1.05448600e+00,  -1.03678365e+00,  -1.02100279e+00,
#         -1.00809861e+00,   1.05182549e+00,   2.14889737e+00,
#          2.17615745e+00,   2.29713597e+00,   2.70025893e+00,
#          4.24613073e+00,   4.58731048e+00,   7.01129825e+00,
#          7.06552181e+00,   7.40792318e+00,   8.14230682e+00,
#          8.78804370e+00,   1.04795937e+01,   1.06902456e+01,
#          1.07107618e+01,   1.14995343e+01,   1.46420167e+01,
#          2.28132573e+01,   2.31657777e+01,   3.23042172e+01,
#          3.45788403e+01,   3.80011476e+01,   3.92183346e+01,
#          4.04601028e+01,   5.34678845e+01,   5.94051890e+01,
#          6.85241030e+01,   6.89796626e+01,   7.24400055e+01,
#          7.52549353e+01,   8.56733282e+01,   1.06232671e+02,
#          1.22128128e+02,   1.25651553e+02,   1.34202415e+02,
#          1.44215353e+02,   2.43685100e+02,   2.56158111e+02,
#          2.56703516e+02])

# %% [markdown]
# Now, do the same thing a whole bunch of times:

# %%
# %%time
thresh = 1.0
niter = 100
pval = 0.05

try: 
    thlo = thresh[0]
    thhi = thresh[1]
except:
    thlo = -thresh
    thhi = thresh

cluster_masses = np.array([])
for ind in np.arange(niter):
    labels = np.random.permutation(alltimes['label'])
    pos = boot.make_thresholded_diff(spectra, labels, hi=thhi)
    neg = boot.make_thresholded_diff(spectra, labels, lo=thlo)

    posclus = boot.label_clusters(pos)
    negclus = boot.label_clusters(neg)

    cluster_masses = np.concatenate([
        cluster_masses, 
        boot.get_cluster_masses(pos, posclus), 
        boot.get_cluster_masses(neg, negclus)
        ])

cluster_masses = np.sort(cluster_masses)
plo = pval / 2.0
phi = 1 - plo
Nlo = np.floor(cluster_masses.size * plo)
Nhi = np.ceil(cluster_masses.size * phi)
Clo = cluster_masses[Nlo]
Chi = cluster_masses[Nhi]
plt.hist(cluster_masses, 50, normed=1);
plt.vlines([Clo, Chi], *plt.ylim(), colors='red', linestyles='dashed')
print Clo, Chi
# Out:
# -212.310901009 365.447094711
# CPU times: user 1min 19s, sys: 2.56 s, total: 1min 22s
# Wall time: 1min 23s

# %% [markdown]
# Let's use this to plot only significant clusters in the real data:

# %%
truelabels = alltimes['label']
signif = boot.threshold_clusters(spectra, truelabels, lo=thlo, hi=thhi, 
                       keeplo=Clo, keephi=Chi)
plot_diff_map(signif, taxis, faxis)

# %% [markdown]
# Now retrieve the original contrast image from the spectra (doing this way saves the cost of computing the spectra all over again):

# %%
truelabels = alltimes['label'].values
img0 = tf._mean_from_events(np.array(spectra)[truelabels == 0], taxis, faxis)
img1 = tf._mean_from_events(np.array(spectra)[truelabels == 1], taxis, faxis)
contrast = img0 / img1

# %% [markdown]
# We'll using masking to eliminate all entries that are not significant:

# %%
mcontrast = contrast.copy()

mcontrast = mcontrast.mask(signif.mask)

# %%
tf.plot_time_frequency(mcontrast);

# %% [markdown]
# Let's try all the above in one go with a method in the LFPset class:

# %%
# %%time
contr_tf, fig = lfp.contrast_time_frequency('17', [stops, pops], Tpre, Tpost, method='wav',
                            normfun=phys.norm_by_trial(baseline_interval))
mcontr, fig = lfp.significant_time_frequency('17', [stops, pops], 
                                             Tpre, Tpost, thresh=1., 
                                             niter=100, method='wav', 
                                             doplot=True, 
                                             normfun=phys.norm_by_trial(baseline_interval))
# Out:
# CPU times: user 1min 44s, sys: 2.78 s, total: 1min 47s
# Wall time: 1min 49s
